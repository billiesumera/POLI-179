# %% [markdown]
# <a href="https://colab.research.google.com/github/billiesumera/POLI-179/blob/main/POLI_179_Bing_Image_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install bing-image-downloader

# %% [markdown]
# # Job 1:Doctor

# %%
! mkdir images

# %%
from bing_image_downloader import downloader
downloader.download("doctor", limit=100,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /content/images/doctor
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://pluspng.com/img-png/doctor-symbol-png-medical-symbol-caduceus-2000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2013/07/12/Health-Environment-Science/Images/iStock_000024597659Large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.publicdomainpictures.net/pictures/210000/velka/doctor-1490804643Rfi.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn6.dissolve.com/p/D2115_277_190/D2115_277_190_1200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.pngall.com/wp-content/uploads/2016/06/Doctor-Symbol-Caduceus-PNG.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://media.npr.org/assets/news/2010/02/25/doctor-3900f8c9b6c5be80f3b2e509eafe9c41d7ad2671.jpg
# ...

# %%
# !ls images/ -alrt
# Out:
# total 12
# drwxr-xr-x 1 root root 4096 May 28 18:10 ..
# drwxr-xr-x 3 root root 4096 May 28 18:10 .
# drwxr-xr-x 2 root root 4096 May 28 18:17 doctor

# %%
# !ls 'images'/'doctor'
# Out:
# Image_100.jpg  Image_25.jpg  Image_40.jpg   Image_56.jpg  Image_71.jpg	Image_87.jpg
# Image_10.jpg   Image_26.jpg  Image_41.jpg   Image_57.jpg  Image_72.png	Image_88.jpg
# Image_11.jpeg  Image_27.jpg  Image_42.jpg   Image_58.png  Image_73.jpg	Image_89.jpg
# Image_12.jpg   Image_28.png  Image_43.jpeg  Image_59.jpg  Image_74.jpg	Image_8.jpg
# Image_13.jpg   Image_29.jpg  Image_44.png   Image_5.png   Image_75.jpg	Image_90.jpg
# Image_14.jpeg  Image_2.jpg   Image_45.jpg   Image_60.jpg  Image_76.jpg	Image_91.jpg
# Image_15.jpg   Image_30.png  Image_46.jpg   Image_61.jpg  Image_77.png	Image_92.jpg
# Image_16.jpg   Image_31.jpg  Image_47.jpg   Image_62.jpg  Image_78.jpg	Image_93.jpg
# Image_17.png   Image_32.png  Image_48.jpg   Image_63.jpg  Image_79.jpg	Image_94.jpg
# Image_18.jpg   Image_33.jpg  Image_49.jpg   Image_64.jpg  Image_7.jpg	Image_95.jpg
# Image_19.jpg   Image_34.jpg  Image_4.jpg    Image_65.jpg  Image_80.jpg	Image_96.jpg
# ...

# %%
from IPython.display import Image
Image("images/doctor/Image_99.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
from IPython.display import Image
Image("images/doctor/Image_5.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Job 2: Police

# %%
from bing_image_downloader import downloader
downloader.download("police", limit=100,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /content/images/police
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.panaynews.net/wp-content/uploads/2018/11/PNP-Police.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://e3.365dm.com/19/08/1600x900/skynews-police-uk-police_4747190.jpg?20190816150001
# [Error]Invalid image, not saving https://e3.365dm.com/19/08/1600x900/skynews-police-uk-police_4747190.jpg?20190816150001
#
# [!] Issue getting: https://e3.365dm.com/19/08/1600x900/skynews-police-uk-police_4747190.jpg?20190816150001
# [!] Error:: Invalid image, not saving https://e3.365dm.com/19/08/1600x900/skynews-police-uk-police_4747190.jpg?20190816150001
#
# [%] Downloading Image #2 from https://unitynewsnetwork.co.uk/wp-content/uploads/2020/04/UK-Metropolitan-police.jpg
# [%] File Downloaded !
#
# ...

# %%
# !ls images/ -alrt

# %%
# !ls 'images'/'police'

# %%
from IPython.display import Image
Image("images/police/Image_99.jpg")

# %%
from IPython.display import Image
Image("images/police/Image_5.jpg")

# %%
from six import BytesIO
from PIL import Image
import numpy as np
import glob
import os

import matplotlib
import matplotlib.pyplot as plt

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Job 3: dancer

# %%
from bing_image_downloader import downloader
downloader.download("dancer", limit=100,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /content/images/dancer
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://balletnews.co.uk/wp-content/uploads/2011/05/IMG_0683a-3.jpg
# [!] Issue getting: http://balletnews.co.uk/wp-content/uploads/2011/05/IMG_0683a-3.jpg
# [!] Error:: Remote end closed connection without response
# [%] Downloading Image #1 from http://www.publicdomainpictures.net/pictures/210000/velka/ballet-dancer-silhouette.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/91/31/34/913134a9286a367cc2dd35cd8445d1dd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.self.com/photos/580911a5a195307571c3e9d0/master/pass/NYCDP_AshleyEllis.jpg?mbid=social_retweet
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://openclipart.org/image/2400px/svg_to_png/231466/Ballet-Dancer-Silhouette.png
# [%] File Downloaded !
#
# ...

# %%
# !ls images/ -alrt
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 May 28 18:10 ..
# drwxr-xr-x 2 root root 4096 May 28 18:17 doctor
# drwxr-xr-x 2 root root 4096 May 28 18:19 police
# drwxr-xr-x 5 root root 4096 May 28 18:19 .
# drwxr-xr-x 2 root root 4096 May 28 18:21 dancer

# %%
# !ls 'images'/'dancer'
# Out:
# Image_100.jpg  Image_25.jpg   Image_40.jpg   Image_56.jpeg  Image_71.jpg  Image_87.jpeg
# Image_10.jpg   Image_26.jpeg  Image_41.jpg   Image_57.jpg   Image_72.jpg  Image_88.jpg
# Image_11.jpg   Image_27.png   Image_42.jpg   Image_58.jpg   Image_73.jpg  Image_89.jpeg
# Image_12.jpg   Image_28.jpg   Image_43.jpg   Image_59.jpg   Image_74.jpg  Image_8.png
# Image_13.png   Image_29.png   Image_44.jpg   Image_5.jpg    Image_75.gif  Image_90.png
# Image_14.jpg   Image_2.jpg    Image_45.jpg   Image_60.jpg   Image_76.jpg  Image_91.jpg
# Image_15.png   Image_30.jpg   Image_46.jpg   Image_61.jpg   Image_77.jpg  Image_92.jpg
# Image_16.jpg   Image_31.jpg   Image_47.jpg   Image_62.jpg   Image_78.jpg  Image_93.jpg
# Image_17.jpg   Image_32.jpg   Image_48.png   Image_63.jpg   Image_79.jpg  Image_94.png
# Image_18.jpg   Image_33.jpg   Image_49.jpg   Image_64.jpg   Image_7.jpg   Image_95.jpg
# Image_19.jpg   Image_34.jpg   Image_4.png    Image_65.jpg   Image_80.jpg  Image_96.jpg
# ...

# %%
from IPython.display import Image
Image("images/dancer/Image_99.jpg")

# %%
from IPython.display import Image
Image("images/dancer/Image_5.jpg")

# %%
def load_image_into_numpy_array(path):
  img_data = open(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape((im_height, im_width, 3)).astype(np.uint8)

# %% [markdown]
# # Job 4: teacher

# %%
! mkdir images
# Out:
# mkdir: cannot create directory ‘images’: File exists

# %%
from bing_image_downloader import downloader
downloader.download("teacher", limit=100,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /content/images/teacher
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://fthmb.tqn.com/bzCTJWqcE4bZCuV_XXuCJw6zfMo=/2121x1414/filters:fill(auto,1)/GettyImages-548929135-59f24924d088c000104ed810.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://ctboom.com/wp-content/uploads/ir.ashx_39.jpg
# [!] Issue getting: http://ctboom.com/wp-content/uploads/ir.ashx_39.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #2 from http://i.huffpost.com/gen/1436630/thumbs/o-TEACHER-facebook.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://i.huffpost.com/gen/1237570/images/o-TEACHER-facebook.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://1.bp.blogspot.com/_lh7OzvarKFc/TU9W86rII_I/AAAAAAAAACg/i8U0Is5HfiM/s1600/800px-Teacher_writing_on_a_Blackboard.jpg
# [%] File Downloaded !
#
# ...

# %%
# !ls images/ -alrt
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 May 28 18:10 ..
# drwxr-xr-x 2 root root 4096 May 28 18:17 doctor
# drwxr-xr-x 2 root root 4096 May 28 18:19 police
# drwxr-xr-x 2 root root 4096 May 28 18:21 dancer
# drwxr-xr-x 6 root root 4096 May 28 18:21 .
# drwxr-xr-x 2 root root 4096 May 28 18:23 teacher

# %%
# !ls 'images'/'teacher'
# Out:
# Image_100.png  Image_23.jpg  Image_37.jpg  Image_50.jpg  Image_64.jpg  Image_78.jpg  Image_91.png
# Image_10.jpg   Image_24.jpg  Image_38.jpg  Image_51.jpg  Image_65.jpg  Image_79.jpg  Image_92.jpg
# Image_11.jpg   Image_25.jpg  Image_39.jpg  Image_52.jpg  Image_66.jpg  Image_7.jpg   Image_93.png
# Image_12.jpg   Image_26.jpg  Image_3.jpg   Image_53.jpg  Image_67.jpg  Image_80.jpg  Image_94.png
# Image_13.jpg   Image_27.jpg  Image_40.jpg  Image_54.jpg  Image_68.jpg  Image_81.jpg  Image_95.png
# Image_14.jpg   Image_28.jpg  Image_41.jpg  Image_55.jpg  Image_69.jpg  Image_82.jpg  Image_96.png
# Image_15.jpg   Image_29.jpg  Image_42.jpg  Image_56.jpg  Image_6.jpg   Image_83.jpg  Image_97.jpg
# Image_16.jpg   Image_2.jpg   Image_43.jpg  Image_57.jpg  Image_70.jpg  Image_84.jpg  Image_98.jpg
# Image_17.jpg   Image_30.jpg  Image_44.jpg  Image_58.jpg  Image_71.jpg  Image_85.jpg  Image_99.jpg
# Image_18.jpg   Image_31.jpg  Image_45.jpg  Image_59.jpg  Image_72.jpg  Image_86.jpg  Image_9.jpg
# ...

# %%
from IPython.display import Image
Image("images/teacher/Image_99.jpg")

# %%
from IPython.display import Image
Image("images/teacher/Image_5.jpg")

# %% [markdown]
# # Job 5: reporter

# %%
from bing_image_downloader import downloader
downloader.download("reporter", limit=100,  output_dir='images', adult_filter_off=True, force_replace=False)
# Out:
# [%] Downloading Images to /content/images/reporter
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://dm0qx8t0i9gc9.cloudfront.net/thumbnails/video/MPaEbz-/videoblocks-medium-shot-of-male-caucasian-news-reporter-with-reportage-from-the-scene_shzar3yxn_thumbnail-1080_01.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newsthump.com/wp-content/uploads/2019/08/reporter-on-the-scene.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://alis.alberta.ca/media/697654/reporter-istock-92403825.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://fthmb.tqn.com/cYP1lnwet2V-Zcdy6oNioE9cC7Y=/768x0/filters:no_upscale()/reporter-questions-5716ea9e3df78c3fa2e75984.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://preaprez.files.wordpress.com/2013/08/reporter.png
# [%] File Downloaded !
#
# ...

# %%
# !ls images/ -alrt
# Out:
# total 28
# drwxr-xr-x 1 root root 4096 May 28 18:10 ..
# drwxr-xr-x 2 root root 4096 May 28 18:17 doctor
# drwxr-xr-x 2 root root 4096 May 28 18:19 police
# drwxr-xr-x 2 root root 4096 May 28 18:21 dancer
# drwxr-xr-x 2 root root 4096 May 28 18:23 teacher
# drwxr-xr-x 7 root root 4096 May 28 18:23 .
# drwxr-xr-x 2 root root 4096 May 28 18:26 reporter

# %%
# !ls 'images'/'reporter'
# Out:
# Image_100.jpg  Image_23.jpg  Image_37.jpg  Image_50.jpg  Image_64.jpg  Image_78.jpg  Image_91.jpg
# Image_10.jpg   Image_24.jpg  Image_38.jpg  Image_51.jpg  Image_65.jpg  Image_79.jpg  Image_92.jpg
# Image_11.jpg   Image_25.jpg  Image_39.jpg  Image_52.png  Image_66.jpg  Image_7.jpg   Image_93.jpg
# Image_12.jpg   Image_26.jpg  Image_3.jpg   Image_53.jpg  Image_67.jpg  Image_80.jpg  Image_94.jpg
# Image_13.jpg   Image_27.jpg  Image_40.png  Image_54.jpg  Image_68.jpg  Image_81.jpg  Image_95.jpg
# Image_14.jpg   Image_28.jpg  Image_41.jpg  Image_55.jpg  Image_69.jpg  Image_82.jpg  Image_96.jpg
# Image_15.jpg   Image_29.jpg  Image_42.jpg  Image_56.jpg  Image_6.jpeg  Image_83.jpg  Image_97.jpg
# Image_16.jpg   Image_2.jpg   Image_43.png  Image_57.jpg  Image_70.jpg  Image_84.jpg  Image_98.jpg
# Image_17.jpg   Image_30.jpg  Image_44.jpg  Image_58.jpg  Image_71.jpg  Image_85.jpg  Image_99.jpg
# Image_18.jpg   Image_31.png  Image_45.jpg  Image_59.jpg  Image_72.jpg  Image_86.jpg  Image_9.png
# ...

# %%
from IPython.display import Image
Image("images/reporter/Image_99.jpg")

# %%
from IPython.display import Image
Image("images/reporter/Image_5.jpeg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...
